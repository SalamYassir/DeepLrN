# %% [markdown]
# <a href="https://colab.research.google.com/github/SalamYassir/DeepLrN/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
import numpy as np
####  create bags
bag_size=100
labels=np.array(y_train)
xArr=np.array(x_train)
print(xArr.shape)
sizel=labels.shape[0]
print(sizel)
sizeX=xArr.shape[0]
InputArr=xArr.reshape(sizeX//bag_size,bag_size,28,28)
LabelArr=labels.reshape(sizel//bag_size,bag_size)
print(LabelArr.shape)
tumerPurity1=np.array([])
tumerPurity7=np.array([])
tumerPurity1_7=np.array([])
keybag=0
for bag in LabelArr:
  tumerPurity1=np.append(tumerPurity1,0)
  tumerPurity7=np.append(tumerPurity7,0)
  tumerPurity1_7=np.append(tumerPurity1_7,0)
  for item in bag:
    if (item== 1 or item== 7):
      tumerPurity1_7[keybag]+=1
    if (item== 1 ):
      tumerPurity1[keybag]+=1
    if (item== 7 ):
      tumerPurity7[keybag]+=1
  tumerPurity1[keybag]=tumerPurity1[keybag]/bag_size
  tumerPurity7[keybag]=tumerPurity7[keybag]/bag_size
  tumerPurity1_7[keybag]=tumerPurity1_7[keybag]/bag_size 
  keybag=keybag+1
# Out:
# (60000, 28, 28)
# 60000
# (600, 100)

# %%
labelsTest=np.array(y_test)
xArrTest=np.array(x_test)
sizelTest=labelsTest.shape[0]
sizeXTest=xArrTest.shape[0]
InputArrTest=xArrTest.reshape(sizeXTest//bag_size,bag_size,28,28)
LabelArrTest=labelsTest.reshape(sizelTest//bag_size,bag_size)
print(LabelArrTest.shape)
tumerPurity1Test=np.array([])
tumerPurity7Test=np.array([])
tumerPurity1_7Test=np.array([])
keybagTest=0
for bagTest in LabelArrTest:
  tumerPurity1Test=np.append(tumerPurity1Test,0)
  tumerPurity7Test=np.append(tumerPurity7Test,0)
  tumerPurity1_7Test=np.append(tumerPurity1_7Test,0)
  for item in bagTest:
    if (item== 1 or item== 7):
      tumerPurity1_7Test[keybagTest]+=1
    if (item== 1 ):
      tumerPurity1Test[keybagTest]+=1
    if (item== 7 ):
      tumerPurity7Test[keybagTest]+=1
  tumerPurity1Test[keybagTest]=tumerPurity1Test[keybagTest]/bag_size
  tumerPurity7Test[keybagTest]=tumerPurity7Test[keybagTest]/bag_size
  tumerPurity1_7Test[keybagTest]=tumerPurity1_7Test[keybagTest]/bag_size
  keybagTest=keybagTest+1
# Out:
# (100, 100)

# %%
import matplotlib.pyplot as plt
# Prepare the data
train_x = range(sizel//bag_size)
test_x = range(sizelTest//bag_size)

# Plot the data
plt.plot(train_x, tumerPurity1,'-',label='x')
plt.plot(train_x, 1-tumerPurity1,'-',label='x`')
# Add a legend
plt.legend('x`')

plt.title('For 1')

# Show the plot
plt.show()
# Plot the data
plt.plot(train_x, tumerPurity7,'-',label='x')
plt.plot(train_x, 1-tumerPurity7,'-',label='x`')
# Add a legend
plt.legend('x`')

plt.title('For 7')
# Show the plot
plt.show()
# Plot the data
plt.plot(train_x, tumerPurity1_7,'-',label='x')
plt.plot(train_x, 1-tumerPurity1_7,'-',label='x`')
# Add a legend
plt.legend('x`')

plt.title('For 1 and 7')
# Show the plot
plt.show()
# Plot the data
plt.plot(test_x, tumerPurity1Test,'-',label='x')
plt.plot(test_x, 1-tumerPurity1Test,'-',label='x`')
# Add a legend
plt.legend('x`')

plt.title('For test 1')

# Show the plot
plt.show()
# Plot the data
plt.plot(test_x, tumerPurity7Test,'-',label='x')
plt.plot(test_x, 1-tumerPurity7Test,'-',label='x`')
# Add a legend
plt.legend('x`')

plt.title('For test 7')

# Show the plot
plt.show()

# Plot the data
plt.plot(test_x, tumerPurity1_7Test,'-',label='x')
plt.plot(test_x, 1-tumerPurity1_7Test,'-',label='x`')
# Add a legend
plt.legend('x`')

plt.title('For 1 and 7 test ')
# Out:
# Text(0.5, 1.0, 'For 1 and 7 test ')

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
model = models.Sequential()
model.add(layers.InputLayer(input_shape=(bag_size,28, 28)))
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Dense(64, activation='relu'))

model.add(layers.Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_23 (Conv2D)          (None, 98, 26, 32)        8096
#
#  max_pooling2d_14 (MaxPoolin  (None, 49, 13, 32)       0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 47, 11, 32)        9248
#
#  max_pooling2d_15 (MaxPoolin  (None, 23, 5, 32)        0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 21, 3, 64)         18496
#
#  dense_18 (Dense)            (None, 21, 3, 64)         4160
#
#  dense_19 (Dense)            (None, 21, 3, 1)          65
#
# ...
# Total params: 40,065
# Trainable params: 40,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=50
model.compile(tf.optimizers.RMSprop(0.001), loss='mse',metrics=['accuracy'])
history =model.fit(InputArr, tumerPurity1_7, epochs=epochs, verbose=1)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 6s 186ms/step - loss: 0.0085 - accuracy: 0.0000e+00
# Epoch 2/50
# 19/19 [==============================] - 3s 180ms/step - loss: 0.0028 - accuracy: 0.0000e+00
# Epoch 3/50
# 19/19 [==============================] - 3s 179ms/step - loss: 0.0025 - accuracy: 0.0000e+00
# Epoch 4/50
# 19/19 [==============================] - 3s 180ms/step - loss: 0.0026 - accuracy: 0.0000e+00
# Epoch 5/50
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0022 - accuracy: 0.0000e+00
# Epoch 6/50
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0019 - accuracy: 0.0000e+00
# Epoch 7/50
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0019 - accuracy: 0.0000e+00
# Epoch 8/50
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0019 - accuracy: 0.0000e+00
# Epoch 9/50
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0021 - accuracy: 0.0000e+00
# Epoch 10/50
# ...

# %%
# summarize history for loss
plt.plot(history.history['loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend('train', loc='upper left')
plt.show()

# %%
results = model.evaluate(InputArrTest, tumerPurity1_7Test)
print("test loss, test acc:", results)
# Out:
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0013 - accuracy: 0.0000e+00
# test loss, test acc: [0.0013217059895396233, 0.0]
